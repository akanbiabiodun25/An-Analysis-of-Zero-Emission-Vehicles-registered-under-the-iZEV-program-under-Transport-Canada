# %% [markdown]
# <a href="https://colab.research.google.com/github/akanbiabiodun25/An-Analysis-of-Zero-Emission-Vehicles-registered-under-the-iZEV-program-under-Transport-Canada/blob/main/Untitled30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read in the CSV file
bank_df = pd.read_csv('/content/drive/MyDrive/bankmarketing_train.csv')

# %%
bank_df['y'] = bank_df['y'].apply(lambda x:1 if x=="yes" else 0)

# %%
bank_df.head(10)
# Out:
#    age           job   marital            education  default housing loan  \
# 0   57    technician   married          high.school       no      no  yes
# 1   55       unknown   married              unknown  unknown     yes   no
# 2   33   blue-collar   married             basic.9y       no      no   no
# 3   36        admin.   married          high.school       no      no   no
# 4   27     housemaid   married          high.school       no     yes   no
# 5   58       retired   married  professional.course       no     yes  yes
# 6   48      services   married          high.school  unknown     yes   no
# 7   51        admin.  divorced    university.degree  unknown     yes   no
# 8   24  entrepreneur   married    university.degree       no     yes  yes
# 9   36    technician  divorced  professional.course       no     yes  yes
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         mon  ...         1    999         1      failure
# ...

# %%
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32950 entries, 0 to 32949
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32950 non-null  int64
#  1   job             32950 non-null  object
#  2   marital         32950 non-null  object
#  3   education       32950 non-null  object
#  4   default         32950 non-null  object
#  5   housing         32950 non-null  object
#  6   loan            32950 non-null  object
#  7   contact         32950 non-null  object
#  8   month           32950 non-null  object
#  9   day_of_week     32950 non-null  object
#  10  duration        32950 non-null  int64
#  11  campaign        32950 non-null  int64
#  12  pdays           32950 non-null  int64
#  13  previous        32950 non-null  int64
#  14  poutcome        32950 non-null  object
#  15  emp.var.rate    32950 non-null  float64
#  16  cons.price.idx  32950 non-null  float64
# ...

# %%
bank_df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m  \
# count  32950.000000    32950.000000   32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654
# std        1.572242        0.578636       4.623004      1.735748
# ...

# %% [markdown]
# VISUALIZATION

# %%
bank_df.hist(bins = 20, figsize = (20,20), color = 'r')
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'campaign'}>],
#        [<Axes: title={'center': 'pdays'}>,
#         <Axes: title={'center': 'previous'}>,
#         <Axes: title={'center': 'emp.var.rate'}>],
#        [<Axes: title={'center': 'cons.price.idx'}>,
#         <Axes: title={'center': 'cons.conf.idx'}>,
#         <Axes: title={'center': 'euribor3m'}>],
#        [<Axes: title={'center': 'nr.employed'}>,
#         <Axes: title={'center': 'y'}>, <Axes: >]], dtype=object)

# %%
deposit_no = bank_df[bank_df['y']==0]
deposit_yes = bank_df[bank_df['y']==1]

# %%
print("Total =", len(bank_df))

print("Number of client will subscribe a term deposit (YES) =", len(deposit_yes))
print("Percentage who could subscribe for deposit =", 1.*len(deposit_yes)/len(bank_df)*100.0, "%")

print("Number of client won't subscribe a term deposit (NO) =", len(deposit_no))
print("Percentage who could not subscribe for deposit =", 1.*len(deposit_no)/len(bank_df)*100.0, "%")
# Out:
# Total = 32950
# Number of client will subscribe a term deposit (YES) = 3692
# Percentage who could subscribe for deposit = 11.204855842185129 %
# Number of client won't subscribe a term deposit (NO) = 29258
# Percentage who could not subscribe for deposit = 88.79514415781487 %

# %%
deposit_no.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  29258.000000  29258.000000  29258.000000  29258.000000  29258.000000
# mean      39.924773    220.275890      2.625812    983.629879      0.134425
# std        9.911543    206.847224      2.864877    122.566916      0.409758
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000     95.000000      1.000000    999.000000      0.000000
# 50%       38.000000    163.000000      2.000000    999.000000      0.000000
# 75%       47.000000    278.000000      3.000000    999.000000      0.000000
# max       95.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m  \
# count  29258.000000    29258.000000   29258.000000  29258.000000
# mean       0.241695       93.601902     -40.612913      3.804037
# std        1.485374        0.559088       4.388949      1.640920
# ...

# %%
deposit_yes.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  3692.000000  3692.000000  3692.000000  3692.000000  3692.000000
# mean     40.955038   551.019231     2.053900   792.149512     0.494583
# std      13.852716   393.480972     1.683125   403.339290     0.868625
# min      17.000000    37.000000     1.000000     0.000000     0.000000
# 25%      31.000000   255.000000     1.000000   999.000000     0.000000
# 50%      37.000000   453.000000     2.000000   999.000000     0.000000
# 75%      50.000000   740.000000     2.000000   999.000000     1.000000
# max      98.000000  3643.000000    23.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed  \
# count   3692.000000     3692.000000    3692.000000  3692.000000  3692.000000
# mean      -1.235049       93.355060     -39.771912     2.122773  5095.068960
# std        1.625132        0.676078       6.121216     1.743888    87.520434
# ...

# %%
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

correlations = bank_df.corr()
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(correlations, annot = True)
# Out:
# <ipython-input-14-e5faeeb4a4e1>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = bank_df.corr()
# <Axes: >

# %%
plt.figure(figsize=[20,20])
plt.subplot(411)
sns.countplot(x = 'age', hue = 'y', data = bank_df)
plt.subplot(412)
sns.countplot(x = 'job', hue = 'y', data = bank_df)
plt.subplot(413)
sns.countplot(x = 'marital', hue = 'y', data = bank_df)
plt.subplot(414)
sns.countplot(x = 'education', hue = 'y', data = bank_df)
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
plt.figure(figsize=[20,20])
plt.subplot(411)
sns.countplot(x = 'campaign', hue = 'y', data = bank_df)
plt.subplot(412)
sns.countplot(x = 'previous', hue = 'y', data = bank_df)
plt.subplot(413)
sns.countplot(x = 'poutcome', hue = 'y', data = bank_df)
plt.subplot(414)
sns.countplot(x = 'y', hue = 'y', data = bank_df)
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %%
# KDE (Kernel Density Estimate) is used for visualizing the Probability Density of a continuous variable.
# KDE describes the probability density at different values in a continuous variable.

plt.figure(figsize=(12,7))

sns.kdeplot(deposit_no['duration'], label = 'people without deposit', shade = True, color = 'b')
sns.kdeplot(deposit_yes['duration'], label = 'people with deposit', shade = True, color = 'r')

plt.xlabel('duration')
# Out:
# <ipython-input-17-2230ca6cdaf4>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(deposit_no['duration'], label = 'people without deposit', shade = True, color = 'b')
# <ipython-input-17-2230ca6cdaf4>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(deposit_yes['duration'], label = 'people with deposit', shade = True, color = 'r')
# Text(0.5, 0, 'duration')

# %%
plt.figure(figsize=(12,7))

sns.kdeplot(deposit_no['age'], label = 'people without deposit', shade = True, color = 'b')
sns.kdeplot(deposit_yes['age'], label = 'people with deposit', shade = True, color = 'r')

plt.xlabel('age')
# Out:
# <ipython-input-18-655559172798>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(deposit_no['age'], label = 'people without deposit', shade = True, color = 'b')
# <ipython-input-18-655559172798>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(deposit_yes['age'], label = 'people with deposit', shade = True, color = 'r')
# Text(0.5, 0, 'age')

# %%
plt.figure(figsize=(12,7))

sns.kdeplot(deposit_no['campaign'], label = 'people without deposit', shade = True, color = 'b')
sns.kdeplot(deposit_yes['campaign'], label = 'people with deposit', shade = True, color = 'r')

plt.xlabel('campaign')
# Out:
# <ipython-input-19-c70e733c5c41>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(deposit_no['campaign'], label = 'people without deposit', shade = True, color = 'b')
# <ipython-input-19-c70e733c5c41>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(deposit_yes['campaign'], label = 'people with deposit', shade = True, color = 'r')
# Text(0.5, 0, 'campaign')

# %% [markdown]
# CREATE TESTING AND TRAINING DATASET & PERFORM DATA CLEANING

# %%
bank_df.head()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
# ...

# %%
df = bank_df[['duration','age','campaign','pdays', 'y']]

# %%
df.head()
# Out:
#    duration  age  campaign  pdays  y
# 0       371   57         1    999  0
# 1       285   55         2    999  0
# 2        52   33         1    999  0
# 3       355   36         4    999  0
# 4       189   27         2    999  0

# %%
#drop the target column before we do train test split
X = df.drop('y',axis=1).values
y = df['y'].values

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
print (X)
# Out:
# [[ 0.44171208  1.62572237 -0.56510616  0.19625052]
#  [ 0.10750799  1.43400743 -0.20325987  0.19625052]
#  [-0.79795191 -0.67485697 -0.56510616  0.19625052]
#  ...
#  [-0.47540611 -1.34585928  0.52043269  0.19625052]
#  [ 0.50000349 -0.86657192 -0.56510616  0.19625052]
#  [-0.30441797 -0.09971214 -0.56510616  0.19625052]]

# %%
y = df['y']

print (y)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32945    0
# 32946    0
# 32947    0
# 32948    0
# 32949    0
# Name: y, Length: 32950, dtype: int64

# %% [markdown]
# TRAIN AND EVALUATE A LOGISTIC REGRESSION CLASSIFIER

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (26360, 4)

# %%
X_test.shape
# Out:
# (6590, 4)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression()
model.fit(X_train , y_train)

y_pred = model.predict(X_test)

# %%
print (y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
print("Accuracy {} %".format( 100 * accuracy_score(y_pred, y_test)))
# Out:
# Accuracy 90.2731411229135 %

# %%
from sklearn.metrics import confusion_matrix , classification_report

cm = confusion_matrix(y_pred, y_test)

sns.heatmap(cm , annot = True)
# Out:
# <Axes: >
